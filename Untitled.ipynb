# %%
import sys
print(sys.executable)
# Out:
# C:\ProgramData\anaconda3\envs\lora\python.exe

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# 2.14.0+cu126
# True
# NVIDIA GeForce RTX 4070 Laptop GPU
